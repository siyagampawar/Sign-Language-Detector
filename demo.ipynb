# %%
import cv2
import matplotlib.pyplot as plt

pic1 = plt.imread('test1.jpg')
plt.imshow(pic1)

# %%
img = cv2.cvtColor(pic1, cv2.COLOR_BGR2GRAY)
plt.imshow(img,cmap='gray')

# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

#Hough Line Transform
dst = cv2.Canny(pic1, 50, 200, None, 3)
cdst = cv2.cvtColor(dst, cv2.COLOR_GRAY2BGR)
lines = cv2.HoughLines(dst, 1, np.pi / 180, 150, None, 0, 0)
# Draw the lines
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv2.line(cdst, pt1, pt2, (0,0,255), 3, cv2.LINE_AA)

plt.imshow(cdst)

# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

#Hough Line Transform
dst = cv2.Canny(img, 50, 200, None, 3)
cdst = cv2.cvtColor(dst, cv2.COLOR_GRAY2BGR)
lines = cv2.HoughLines(dst, 1, np.pi / 180, 150, None, 0, 0)
# Draw the lines
if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv2.line(cdst, pt1, pt2, (0,0,255), 3, cv2.LINE_AA)

plt.imshow(cdst)

# %%
import os
from PIL import Image
from rembg import remove
img = Image.open("test1.jpg")
output = img.convert("L")
output =remove(output)
plt.imshow(output)
#output.save("",format="PNG")

# %%
from PIL import Image
from PIL import ImageFilter

# Open an already existing image
imageObject = output
# imageObject.show();

# Apply sharp filter
sharpened1 = imageObject.filter(ImageFilter.SHARPEN);
sharpened2 = sharpened1.filter(ImageFilter.SHARPEN);

# Show the sharpened images
# sharpened1.show();
# sharpened2.show();
plt.imshow(sharpened1)
plt.imshow(sharpened2)

# %%
# Importing necessary functions
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img

# Initialising the ImageDataGenerator class.
# We will pass in the augmentation parameters in the constructor.
datagen = ImageDataGenerator(
		rotation_range = 40,
		shear_range = 0.2,
		zoom_range = 0.2,
		horizontal_flip = True,
		brightness_range = (0.5, 1.5))

# Loading a sample image
path =  r'C:\Users\Siyag\OneDrive\Desktop\New folder\DL PROJECT\test1.jpg'
img = load_img(path) 
# Converting the input sample image to an array
x = img_to_array(img)
# Reshaping the input image
x = x.reshape((1, ) + x.shape) 

# Generating and saving 5 augmented samples 
# using the above defined parameters. 
i = 0
for batch in datagen.flow(x, batch_size = 1,
						save_to_dir ='preview', 
						save_prefix ='image', save_format ='jpeg'):
	i += 1
	if i > 5:
		break
# Out:
# WARNING:tensorflow:From C:\Users\Siyag\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
pic1.shape
# Out:
# (128, 128, 3)
